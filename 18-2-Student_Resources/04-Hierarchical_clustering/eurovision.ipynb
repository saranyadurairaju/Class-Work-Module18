# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster, linkage, dendrogram
import pandas as pd
import numpy as np
from pathlib import Path

# %%
file = '../Resources/eurovision.csv'
df = pd.read_csv(file)
df.head()
# Out:
#   From country  Armenia  Austria  Azerbaijan  Belarus  Denmark  Finland  \
# 0      Albania     13.0      6.0        15.0     23.0     21.0     17.0
# 1      Armenia      1.0     14.0        25.0      3.0     10.0     21.0
# 2      Austria      1.0      1.0        24.0     20.0     16.0      7.0
# 3   Azerbaijan     25.0     10.0         1.0      4.0     19.0     20.0
# 4      Belarus      2.0     14.0         8.0      1.0     18.0     16.0
#
#    France  Germany  Greece  ...  Romania  Russia  San Marino  Slovenia  Spain  \
# 0    12.0      7.0     9.0  ...     16.0    25.0         8.0      14.0    1.0
# 1    18.0      5.0     4.0  ...     20.0     2.0         8.0      17.0    9.0
# 2    18.0     12.0    19.0  ...      3.0    17.0        25.0      11.0   15.0
# 3    22.0     23.0     7.0  ...      5.0     1.0         8.0      15.0   12.0
# 4    24.0     15.0     5.0  ...     10.0     1.0        19.0      21.0   20.0
#
#    Sweden  Switzerland  The Netherlands  Ukraine  United Kingdom
# 0     4.0         26.0             18.0     19.0            11.0
# 1    12.0          6.0              7.0     15.0            22.0
# 2     5.0          8.0              2.0      6.0            22.0
# 3    13.0         11.0             17.0      2.0            14.0
# 4    12.0         11.0              9.0      3.0            23.0
#
# [5 rows x 27 columns]

# %%
labels = df['From country'].values
data = df.drop('From country', axis=1)

# %%
data.head()
# Out:
#    Armenia  Austria  Azerbaijan  Belarus  Denmark  Finland  France  Germany  \
# 0     13.0      6.0        15.0     23.0     21.0     17.0    12.0      7.0
# 1      1.0     14.0        25.0      3.0     10.0     21.0    18.0      5.0
# 2      1.0      1.0        24.0     20.0     16.0      7.0    18.0     12.0
# 3     25.0     10.0         1.0      4.0     19.0     20.0    22.0     23.0
# 4      2.0     14.0         8.0      1.0     18.0     16.0    24.0     15.0
#
#    Greece  Hungary  ...  Romania  Russia  San Marino  Slovenia  Spain  Sweden  \
# 0     9.0      3.0  ...     16.0    25.0         8.0      14.0    1.0     4.0
# 1     4.0     19.0  ...     20.0     2.0         8.0      17.0    9.0    12.0
# 2    19.0      4.0  ...      3.0    17.0        25.0      11.0   15.0     5.0
# 3     7.0      3.0  ...      5.0     1.0         8.0      15.0   12.0    13.0
# 4     5.0      6.0  ...     10.0     1.0        19.0      21.0   20.0    12.0
#
#    Switzerland  The Netherlands  Ukraine  United Kingdom
# 0         26.0             18.0     19.0            11.0
# 1          6.0              7.0     15.0            22.0
# 2          8.0              2.0      6.0            22.0
# 3         11.0             17.0      2.0            14.0
# 4         11.0              9.0      3.0            23.0
#
# [5 rows x 26 columns]

# %%
labels[:5]
# Out:
# array(['Albania', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus'],
#       dtype=object)

# %%
mergings = linkage(data, method='ward')

# %%
plt.figure(figsize=(14,6))
dendrogram(mergings,
          labels=np.array(labels),
          leaf_rotation=90,
          leaf_font_size=12)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=2,
                               affinity='euclidean',
                               linkage='ward')

# %%
model.fit(data)

# %%
cluster_labels = model.labels_

# %%
cluster_labels
